# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[2, 5, 1],
              [0, 5, 3]])
x
# Out:
# array([[2, 5, 1],
#        [0, 5, 3]])

# %%
# tampilkan ukuran dari matrix X
x.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x[0:, 0]
# Out:
# array([2, 0])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x[1:,]
# Out:
# array([[0, 5, 3]])

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch
x_pt = torch.tensor([[2, 5, 1],
                     [0, 5, 3]])
x_pt
# Out:
# tensor([[2, 5, 1],
#         [0, 5, 3]])

# %%
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
x_pt[0:, 0]
# Out:
# tensor([2, 0])

# %%
x_pt[1:,]
# Out:
# tensor([[0, 5, 3]])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf
x_tf = tf.Variable([[2, 5, 1],
                    [0, 5, 3]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[2, 5, 1],
#        [0, 5, 3]], dtype=int32)>
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[2, 5, 1],
#        [0, 5, 3]], dtype=int32)>

# %%
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
x_tf[0:, 0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 0], dtype=int32)>

# %%
x_tf[1:, ]
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[0, 5, 3]], dtype=int32)>
