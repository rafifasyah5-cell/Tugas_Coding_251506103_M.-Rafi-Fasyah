# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 53
x
# Out:
# 53

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 1053
y
# Out:
# 1053

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum  = x + y
py_sum
# Out:
# 1106

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 5.3
x_float
# Out:
# 5.3

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 1058.3

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
x_tf = tf.Variable(53, dtype=tf.int32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=53>

# %%
x_tf.set_shape
# Out:
# <bound method BaseResourceVariable.set_shape of <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=53>>

# %%
y_tf = tf.Variable(1053, dtype=tf.int32)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=1053>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1106>

# %%
tf_sum = x_tf + y_tf
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1106>

# %%
tf_sum.numpy()
# Out:
# np.int32(1106)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int32

# %%
tf_float = tf.Variable(5.3, dtype=tf.float32)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.300000190734863>
