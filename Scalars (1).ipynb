# %%
# 1. buat variabel skalar x dan simpan suatu nilai skalar
x = 53
x
# Out:
# 53

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 1053
y
# Out:
# 1053

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum  = x + y
py_sum
# Out:
# 1106

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 5.3
x_float
# Out:
# 5.3

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 1058.3

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
x_tf = tf.Variable(53)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=53>

# %%
type(x_tf)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
y_tf = tf.Variable(1053)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=1053>

# %%
type(y_tf)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
py_sum_tf = x_tf + y_tf
py_sum_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1106>

# %%
x_tf_float = tf.Variable(5.3)
x_tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.300000190734863>

# %%
# Tidak bisa dijumlahkan karena beda tipe data
float_sum_tf = x_tf_float + y_tf
float_sum_tf
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_15822/1970397959.py in <cell line: 0>()
#       1 # Tidak bisa dijumlahkan karena beda tipe data
# ----> 2 float_sum_tf = x_tf_float + y_tf
#       3 float_sum_tf
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variables.py in _run_op(a, *args, **kwargs)
#    1014     def _run_op(a, *args, **kwargs):
#    1015       # pylint: disable=protected-access
# -> 1016       return tensor_oper(a.value(), *args, **kwargs)
#    1017
#    1018     functools.update_wrapper(_run_op, tensor_oper)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# ...

# %%
type(x_tf_float)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
x_pt = torch.tensor(53)
x_pt
# Out:
# tensor(53)

# %%
type(x_pt)
# Out:
# torch.Tensor

# %%
y_pt = torch.tensor(1053)
y_pt
# Out:
# tensor(1053)

# %%
type(y_pt)
# Out:
# torch.Tensor

# %%
py_sum_pt = x_pt + y_pt
py_sum_pt
# Out:
# tensor(1106)

# %%
x_pt_float = torch.tensor(5.3)
x_pt_float
# Out:
# tensor(5.3000)

# %%
float_sum_pt = x_pt_float + y_pt
float_sum_pt
# Out:
# tensor(1058.3000)

# %%
type(x_pt_float)
# Out:
# torch.Tensor
